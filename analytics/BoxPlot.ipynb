# %% [markdown]
# total_bill : total price of meal
#
# tip: tip
#
# sex: gender of people who pay bill (0=male,1=female)
#
# smoker : is there a smokers ? (0=no,1=yes)
#
# day: 3=thur,4=fri,5=sat,6=sun
#
# time : when ? (0=Day,1=Night)

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
df = tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.shape
# Out:
# (244, 7)

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
sns.boxplot(x = df['total_bill'] , orient = 'v')

# %%
sns.boxplot( x = 'day', y = 'total_bill',data = df);

# %%
sns.boxplot( x = 'size', y = 'total_bill',data = df);

# %%
sns.boxplot(x='time',y='total_bill', data = df);

# %%
# if there are smokers in the group , 
#we might say that they pay more
sns.boxplot(x='day',y='total_bill',hue = 'sex', data = df);

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-326d2ba41759> in <module>
# ----> 1 sns.boxplot(x='smokers',y='total_bill', data = df);
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # Linear regression

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
model = LinearRegression()

x = np.array(df['size']).reshape(-1,1)
y = np.array(df['total_bill']).reshape(-1,1)
model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model = LinearRegression().fit(x,y)

# %%
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.3579809958697491

# %%
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# intercept: [5.39499823]
# slope: [[5.60030372]]

# %%
new_model = LinearRegression().fit(x, y.reshape((-1, 1)))
print('intercept:', new_model.intercept_)
print('slope:', new_model.coef_)
# Out:
# intercept: [5.39499823]
# slope: [[5.60030372]]

# %%
y_pred = model.predict(x)
print('predicted response:', y_pred, sep='\n')
# Out:
# predicted response:
# [[16.59560567]
#  [22.19590939]
#  [22.19590939]
#  [16.59560567]
#  [27.79621311]
#  [27.79621311]
#  [16.59560567]
#  [27.79621311]
#  [16.59560567]
#  [16.59560567]
#  [16.59560567]
#  [27.79621311]
#  [16.59560567]
#  [27.79621311]
#  [16.59560567]
#  [16.59560567]
#  [22.19590939]
#  [22.19590939]
#  [22.19590939]
#  [22.19590939]
#  [16.59560567]
#  [16.59560567]
#  [16.59560567]
#  [27.79621311]
#  [16.59560567]
#  [27.79621311]
#  [16.59560567]
#  [16.59560567]
#  [16.59560567]
#  [16.59560567]
#  [16.59560567]
#  [27.79621311]
#  [16.59560567]
#  [27.79621311]
#  [16.59560567]
#  [22.19590939]
#  [22.19590939]
#  [22.19590939]
#  [22.19590939]
#  [22.19590939]
#  [22.19590939]
#  [16.59560567]
#  [16.59560567]
#  [16.59560567]
#  [27.79621311]
#  [16.59560567]
#  [16.59560567]
#  [27.79621311]
#  [22.19590939]
#  [16.59560567]
#  [16.59560567]
#  [16.59560567]
#  [27.79621311]
#  [16.59560567]
#  [27.79621311]
#  [16.59560567]
#  [27.79621311]
# ...

# %%
plt.scatter(x,y)
plt.plot(x,y_pred,color = 'red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9d771f9454be> in <module>
# ----> 1 plt.scatter(x,y)
#       2 plt.plot(x,y_pred,color = 'red')
#       3 plt.show()
#
# NameError: name 'plt' is not defined
