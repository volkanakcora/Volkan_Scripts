# %%
class Veribilimci():
    print("bu bir siniftir")
    bolum = ''
    deneyim_yili = 0
    sql = 'Evet'
    bildigi_diller = ['ingilizce','almanca','japonca']
    
Veribilimci.sql
# Out:
# bu bir siniftir
# 'Evet'

# %%
Veribilimci.sql = "hayir"

# %%
Veribilimci.sql
# Out:
# 'hayir'

# %%
volkan = Veribilimci()

# %%
volkan.bildigi_diller
# Out:
# ['ingilizce', 'almanca', 'japonca']

# %%
volkan.bildigi_diller.append('python')

# %%
volkan.bildigi_diller
# Out:
# ['ingilizce', 'almanca', 'japonca', 'python']

# %%
veli = Veribilimci()

# %%
veli.bildigi_diller
# Out:
# ['ingilizce', 'almanca', 'japonca', 'python']

# %%
#ornek ozellikleri

# %%
class VeriBilimci():
    def __init__(self):
        self.bildigi_diller = []

# %%
ali = Veribilimci()
veli = Veribilimci()

# %%
veli.bildigi_diller.append('pyhton')

# %%
class VeriBilimci():
    bildigi_diller = ['R','Python','SQL']
    def __init__(self):
        self.bildigi_diller = []

# %%
ali = Veribilimci()

# %%
ali.bildigi_diller.append('R')

# %%
ali.bildigi_diller
# Out:
# ['ingilizce', 'almanca', 'japonca', 'python', 'R', 'pyhton', 'R']
