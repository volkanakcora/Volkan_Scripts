# %%
mylist = ["volkan","ahmet","selim","uhammet"]
mylist[0] = "orosbucocu"

# %%
mylist.append("six")

# %%
mylist
# Out:
# ['orosbucocu', 'ahmet', 'selim', 'uhammet', 'six']

# %%
#eklemek için

mylist.append("seven")

# %%
mylist
# Out:
# ['orosbucocu', 'ahmet', 'selim', 'uhammet', 'six', 'seven']

# %%
mylist.pop(0)
# Out:
# 'orosbucocu'

# %%
mylist.sort()

# %%
my_sorter_list =mylist.sort()

# %%
print(my_sorter_list)
# Out:
# None

# %%
#### sets

myset = set()

# %%
##booleans

True
# Out:
# True

# %%
# %%writefile myfile.txt
# Hello thi is a text file
# this is second line
# this is third one
# Out:
# Overwriting myfile.txt

# %%
myfile = open("myfile.txt")

# %%
contents = myfile.read()

# %%
contents
# Out:
# 'Hello thi is a text file\nthis is second line\nthis is third one\n'

# %%
pwd
# Out:
# 'C:\\Users\\volka'

# %%
with open("myfile.txt") as mynewfile:
    contents = mynewfile.read()
    
print(contents)
# Out:
# Hello thi is a text file
# this is second line
# this is third one

# %%
with open("myfile.txt",)
# Out:
#   File "<ipython-input-18-688935cf71f7>", line 1
#     with open("myfile.txt",)
#                             ^
# SyntaxError: invalid syntax

# %%
abi =  int(input("lütfen sayi giriniz"))

if abi == 1 :
    print("bu sayi bir")
elif abi == 2 :
    print("bu sayi 2")
elif abi == 3 :
    print("bu sayi 3")
else:
    print("bu sayi 3 ten büyük")

# %%
x = 0
while x<5:
    print(f"the current value of x is {x}")
    x = x + 1

# %%
t = [0,1,2,3,4]

for i in t:
    i = i+1
    print(f"the current value of t is:",i)

# %%
##Break , continue , pass

# %%
x = 0

while x<6:
    if x == 4:
        break
    x +=1
    print(x)
# Out:
# 1
# 2
# 3
# 4
