# %% [markdown]
# PANDAS

# %%
import pandas as pd
import numpy as np

# %%
pd.Series([1,2,3,4])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
seri = pd.Series([1,2,3,4])

# %%
seri.axes
# Out:
# [RangeIndex(start=0, stop=4, step=1)]

# %%
seri.ndim
# Out:
# 1

# %%
seri.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
pd.Series([1,5,0.9,34] , index = [1,3,5,7])
# Out:
# 1     1.0
# 3     5.0
# 5     0.9
# 7    34.0
# dtype: float64

# %%
pd.Series([1,5,0.9,34] , index = ['a',"b",'c',"d"])
# Out:
# a     1.0
# b     5.0
# c     0.9
# d    34.0
# dtype: float64

# %% [markdown]
# # Serilerde Eleman işlemleri

# %%
seri = pd.Series([121,200,150,99],
                index =["rej","loj","cart","rf"])
seri
# Out:
# rej     121
# loj     200
# cart    150
# rf       99
# dtype: int64

# %%
seri[["rej","loj"]]
# Out:
# rej    121
# loj    200
# dtype: int64
