# %%
import numpy as np
prices = np.random.randint(10,110,1000)
prices.mean()
# Out:
# 59.552

# %%
import statsmodels.stats.api as sms

# %% [markdown]
# # The result ıs that our customers can afford these prices for our product.

# %%
sms.DescrStatsW(prices).tconfint_mean()
# Out:
# (57.74801958186289, 61.35598041813711)
