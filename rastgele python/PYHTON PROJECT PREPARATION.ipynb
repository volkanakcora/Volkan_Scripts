# %%
##OLUŞTURMA VE BİÇİMLENDİRME

isimler = ["ali","veli","volkan"]

for i in isimler:
    print("isimler : " , i , sep = "")
    
print(*enumerate(isimler,1))    # data'ya numaralandırma sağlar .
# Out:
# isimler : ali
# isimler : veli
# isimler : volkan
# (1, 'ali') (2, 'veli') (3, 'volkan')
# True

# %%
# Dizi içi tip sorgulamaları

"mvk".isalpha()
# Out:
# True

# %%
## Elemanlarına ve Eleman indexleri erişmek.
isim = "volkan eymir akçora"

isim.index("a")
# Out:
# ['', '']

# %%
isim.index("o",5)
# Out:
# 14

# %%
## Başlangıç ve Bitiş karakterlerini sorgulamak # startswith() , endswith()#
isim.startswith("v")
# Out:
# True

# %%
  sorted(isim)  ##alfabetik sıralama yapmaya yarar
# Out:
# ['a',
#  'a',
#  'a',
#  'e',
#  'i',
#  'k',
#  'k',
#  'l',
#  'm',
#  'n',
#  'o',
#  'o',
#  'r',
#  'r',
#  'v',
#  'y',
#  'ç']

# %%
## KARAKTERLERİ BÖLMEK

isim.split("a")
# Out:
# ['volk', 'n eymir ', 'kçor', '']

# %%
## Büyük Küçük Harf İşlemleri , title() ##

isim = "volkan eymir akçora"
isim.upper()
# Out:
# 'VOLKAN EYMIR AKÇORA'

# %%
isim.lower()
# Out:
# 'volkan eymir akçora'

# %%
## capitalize () & Title ()& swapcase()

# %%
isim = "volkan eymir akçora"

# %%
isim.capitalize()
# Out:
# 'Volkan eymir akçora'

# %%
isim.title()
# Out:
# 'Volkan Eymir Akçora'

# %%
isim.swapcase()
# Out:
# 'VOLKAN EYMIR AKÇORA'

# %%
##İstenmeyen karakterleri kırpmak  : strip(), Istrip(), rsting()

# %%
isim = " hello "

# %%
isim.strip()  # istenmeyen karakterleri kırpar.
# Out:
# 'hello'

# %%
isim = "*hello*"

# %%
isim.rstrip("*")
# Out:
# '*hello'

# %%
isim.lstrip("*")
# Out:
# 'hello*'

# %%
## Join :  Bölünmüş yada zaten bölük olan ifadelerin birleştirilmesi ##

# %%
 isim = "Volkan Eymir Akçora"

# %%
ayrik = isim.split()

# %%
ayrik
# Out:
# ['Volkan', 'Eymir', 'Akçora']

# %%
joiner = ""

# %%
joiner.join(ayrik)
# Out:
# 'VolkanEymirAkçora'

# %%
## Eleman değiştirme : Replace() , str.maketrans(),translate()

# %%
isim.replace("V","c")
# Out:
# 'colkan Eymir Akçora'

# %%
ifade = " Bu ifade içerisinde bazı türkçe harfler vardır"

# %%
duzeltilecek_harfler = "çiiçü"

# %%
duzeltilmis_harfler = "cııcu"

# %%
alfabe_duzeltme = str.maketrans(duzeltilecek_harfler,duzeltilmis_harfler)    # bu fonksyon sana düzeltmilmiş olarak verir

# %%
ifade.translate(alfabe_duzeltme)   # . translate
# Out:
# ' Bu ıfade ıcerısınde bazı turkce harfler vardır'

# %%
## CONTAINS

# %%
import pandas as pd 
isimler = ["ayşe","Ayşe","ali","aali","Ali","veli","mehmet","berkcan"]
v = pd.Series(isimler)

# %%
v
# Out:
# 0       ayşe
# 1       Ayşe
# 2        ali
# 3       aali
# 4        Ali
# 5       veli
# 6     mehmet
# 7    berkcan
# dtype: object

# %%
v.str.contains("al")
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
v[v.str.contains("al")]
# Out:
# 2     ali
# 3    aali
# dtype: object

# %%
v.str.contains("al").sum()
# Out:
# 2

# %%
v.str.contains("[aA]li").sum()   #ıf you want to choose both "a" and "A"
# Out:
# 3
